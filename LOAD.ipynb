# %% [markdown]
# <a href="https://colab.research.google.com/github/saba-0h/Python-for-ML-090/blob/main/LOAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/employees details.csv' # Replace with your actual path
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
#
#                          E Mail     Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 2        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 3         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 4  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
#
#   Mother's Maiden Name  Salary
# 0                Lewis  168251
# 1                Perry   51063
# 2               Taylor   50155
# ...

# %%
print(df.shape)
# Out:
# (100, 11)

# %%
print('First Name',df['First Name'].head())
# Out:
# First Name 0        Lois
# 1      Brenda
# 2         Joe
# 3       Diane
# 4    Benjamin
# Name: First Name, dtype: object

# %%
#Gt the particular row
print("Particular", df.loc[10])
# Out:
# Particular Emp ID                                  231469
# Name Prefix                                Mr.
# First Name                               Ralph
# Middle Initial                               L
# Last Name                               Flores
# Gender                                       M
# E Mail                  ralph.flores@yahoo.com
# Father's Name                     Terry Flores
# Mother's Name                  Michelle Flores
# Mother's Maiden Name                     Moore
# Salary                                  118457
# Name: 10, dtype: object

# %%
print(df[df['Salary']==168251])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
#
#                     E Mail  Father's Name Mother's Name Mother's Maiden Name  \
# 0  lois.walker@hotmail.com  Donald Walker  Helen Walker                Lewis
#
#    Salary
# 0  168251

# %%
#make an average of total marks
d=df['Salary']/5
print(d.head())
# Out:
# 0    33650.2
# 1    10212.6
# 2    10031.0
# 3    36058.8
# 4    23528.4
# Name: Salary, dtype: float64
